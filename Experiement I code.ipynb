# %%
import numpy as np
import pandas as pd

# %%
train_full = pd.read_csv("train.csv")

# %%
train_full.shape
# Out:
# (30471, 292)

# %%
train_cleaned = train_full.drop(['id','timestamp'], axis=1)

# %%
train_cleaned.shape
# Out:
# (30471, 290)

# %%
y = train_cleaned.price_doc

# %%
y.shape
# Out:
# (30471,)

# %%
X_train_cleaned = train_cleaned.drop(['price_doc'], axis=1)

# %%
X_train_cleaned.shape
# Out:
# (30471, 289)

# %%
categorical_cols = [cname for cname in X_train_cleaned.columns if
                    X_train_cleaned[cname].nunique() < 10 and 
                    X_train_cleaned[cname].dtype == "object"]

# %%
numerical_cols = [cname for cname in X_train_cleaned.columns if 
                X_train_cleaned[cname].dtype in ['int64', 'float64']]

# %%
categorical_cols
# Out:
# ['product_type',
#  'culture_objects_top_25',
#  'thermal_power_plant_raion',
#  'incineration_raion',
#  'oil_chemistry_raion',
#  'radiation_raion',
#  'railroad_terminal_raion',
#  'big_market_raion',
#  'nuclear_reactor_raion',
#  'detention_facility_raion',
#  'water_1line',
#  'big_road1_1line',
#  'railroad_1line',
#  'ecology']

# %%
len(categorical_cols)
# Out:
# 14

# %%
numerical_cols
# Out:
# ['full_sq',
#  'life_sq',
#  'floor',
#  'max_floor',
#  'material',
#  'build_year',
#  'num_room',
#  'kitch_sq',
#  'state',
#  'area_m',
#  'raion_popul',
#  'green_zone_part',
#  'indust_part',
#  'children_preschool',
#  'preschool_quota',
#  'preschool_education_centers_raion',
#  'children_school',
#  'school_quota',
#  'school_education_centers_raion',
#  'school_education_centers_top_20_raion',
#  'hospital_beds_raion',
#  'healthcare_centers_raion',
#  'university_top_20_raion',
#  'sport_objects_raion',
#  'additional_education_raion',
#  'culture_objects_top_25_raion',
#  'shopping_centers_raion',
#  'office_raion',
#  'full_all',
#  'male_f',
#  'female_f',
#  'young_all',
#  'young_male',
#  'young_female',
#  'work_all',
#  'work_male',
#  'work_female',
#  'ekder_all',
#  'ekder_male',
#  'ekder_female',
#  '0_6_all',
#  '0_6_male',
#  '0_6_female',
#  '7_14_all',
#  '7_14_male',
#  '7_14_female',
#  '0_17_all',
#  '0_17_male',
#  '0_17_female',
#  '16_29_all',
#  '16_29_male',
#  '16_29_female',
#  '0_13_all',
#  '0_13_male',
#  '0_13_female',
#  'raion_build_count_with_material_info',
#  'build_count_block',
#  'build_count_wood',
#  'build_count_frame',
#  'build_count_brick',
#  'build_count_monolith',
#  'build_count_panel',
#  'build_count_foam',
#  'build_count_slag',
#  'build_count_mix',
#  'raion_build_count_with_builddate_info',
#  'build_count_before_1920',
#  'build_count_1921-1945',
#  'build_count_1946-1970',
#  'build_count_1971-1995',
#  'build_count_after_1995',
#  'ID_metro',
#  'metro_min_avto',
#  'metro_km_avto',
#  'metro_min_walk',
#  'metro_km_walk',
#  'kindergarten_km',
#  'school_km',
#  'park_km',
#  'green_zone_km',
#  'industrial_km',
#  'water_treatment_km',
#  'cemetery_km',
#  'incineration_km',
#  'railroad_station_walk_km',
#  'railroad_station_walk_min',
#  'ID_railroad_station_walk',
#  'railroad_station_avto_km',
#  'railroad_station_avto_min',
#  'ID_railroad_station_avto',
#  'public_transport_station_km',
#  'public_transport_station_min_walk',
#  'water_km',
#  'mkad_km',
#  'ttk_km',
#  'sadovoe_km',
#  'bulvar_ring_km',
#  'kremlin_km',
#  'big_road1_km',
#  'ID_big_road1',
#  'big_road2_km',
#  'ID_big_road2',
#  'railroad_km',
#  'zd_vokzaly_avto_km',
#  'ID_railroad_terminal',
#  'bus_terminal_avto_km',
#  'ID_bus_terminal',
#  'oil_chemistry_km',
#  'nuclear_reactor_km',
#  'radiation_km',
#  'power_transmission_line_km',
#  'thermal_power_plant_km',
#  'ts_km',
#  'big_market_km',
#  'market_shop_km',
#  'fitness_km',
#  'swim_pool_km',
#  'ice_rink_km',
#  'stadium_km',
#  'basketball_km',
#  'hospice_morgue_km',
#  'detention_facility_km',
#  'public_healthcare_km',
#  'university_km',
#  'workplaces_km',
#  'shopping_centers_km',
#  'office_km',
#  'additional_education_km',
#  'preschool_km',
#  'big_church_km',
#  'church_synagogue_km',
#  'mosque_km',
#  'theater_km',
#  'museum_km',
#  'exhibition_km',
#  'catering_km',
#  'green_part_500',
#  'prom_part_500',
#  'office_count_500',
#  'office_sqm_500',
#  'trc_count_500',
#  'trc_sqm_500',
#  'cafe_count_500',
#  'cafe_sum_500_min_price_avg',
#  'cafe_sum_500_max_price_avg',
#  'cafe_avg_price_500',
#  'cafe_count_500_na_price',
#  'cafe_count_500_price_500',
#  'cafe_count_500_price_1000',
#  'cafe_count_500_price_1500',
#  'cafe_count_500_price_2500',
#  'cafe_count_500_price_4000',
#  'cafe_count_500_price_high',
#  'big_church_count_500',
#  'church_count_500',
#  'mosque_count_500',
#  'leisure_count_500',
#  'sport_count_500',
#  'market_count_500',
#  'green_part_1000',
#  'prom_part_1000',
#  'office_count_1000',
#  'office_sqm_1000',
#  'trc_count_1000',
#  'trc_sqm_1000',
#  'cafe_count_1000',
#  'cafe_sum_1000_min_price_avg',
#  'cafe_sum_1000_max_price_avg',
#  'cafe_avg_price_1000',
#  'cafe_count_1000_na_price',
#  'cafe_count_1000_price_500',
#  'cafe_count_1000_price_1000',
#  'cafe_count_1000_price_1500',
#  'cafe_count_1000_price_2500',
#  'cafe_count_1000_price_4000',
#  'cafe_count_1000_price_high',
#  'big_church_count_1000',
#  'church_count_1000',
#  'mosque_count_1000',
#  'leisure_count_1000',
#  'sport_count_1000',
#  'market_count_1000',
#  'green_part_1500',
#  'prom_part_1500',
#  'office_count_1500',
#  'office_sqm_1500',
#  'trc_count_1500',
#  'trc_sqm_1500',
#  'cafe_count_1500',
#  'cafe_sum_1500_min_price_avg',
#  'cafe_sum_1500_max_price_avg',
#  'cafe_avg_price_1500',
#  'cafe_count_1500_na_price',
#  'cafe_count_1500_price_500',
#  'cafe_count_1500_price_1000',
#  'cafe_count_1500_price_1500',
#  'cafe_count_1500_price_2500',
#  'cafe_count_1500_price_4000',
#  'cafe_count_1500_price_high',
#  'big_church_count_1500',
#  'church_count_1500',
#  'mosque_count_1500',
#  'leisure_count_1500',
#  'sport_count_1500',
#  'market_count_1500',
#  'green_part_2000',
#  'prom_part_2000',
#  'office_count_2000',
#  'office_sqm_2000',
#  'trc_count_2000',
#  'trc_sqm_2000',
#  'cafe_count_2000',
#  'cafe_sum_2000_min_price_avg',
#  'cafe_sum_2000_max_price_avg',
#  'cafe_avg_price_2000',
#  'cafe_count_2000_na_price',
#  'cafe_count_2000_price_500',
#  'cafe_count_2000_price_1000',
#  'cafe_count_2000_price_1500',
#  'cafe_count_2000_price_2500',
#  'cafe_count_2000_price_4000',
#  'cafe_count_2000_price_high',
#  'big_church_count_2000',
#  'church_count_2000',
#  'mosque_count_2000',
#  'leisure_count_2000',
#  'sport_count_2000',
#  'market_count_2000',
#  'green_part_3000',
#  'prom_part_3000',
#  'office_count_3000',
#  'office_sqm_3000',
#  'trc_count_3000',
#  'trc_sqm_3000',
#  'cafe_count_3000',
#  'cafe_sum_3000_min_price_avg',
#  'cafe_sum_3000_max_price_avg',
#  'cafe_avg_price_3000',
#  'cafe_count_3000_na_price',
#  'cafe_count_3000_price_500',
#  'cafe_count_3000_price_1000',
#  'cafe_count_3000_price_1500',
#  'cafe_count_3000_price_2500',
#  'cafe_count_3000_price_4000',
#  'cafe_count_3000_price_high',
#  'big_church_count_3000',
#  'church_count_3000',
#  'mosque_count_3000',
#  'leisure_count_3000',
#  'sport_count_3000',
#  'market_count_3000',
#  'green_part_5000',
#  'prom_part_5000',
#  'office_count_5000',
#  'office_sqm_5000',
#  'trc_count_5000',
#  'trc_sqm_5000',
#  'cafe_count_5000',
#  'cafe_sum_5000_min_price_avg',
#  'cafe_sum_5000_max_price_avg',
#  'cafe_avg_price_5000',
#  'cafe_count_5000_na_price',
#  'cafe_count_5000_price_500',
#  'cafe_count_5000_price_1000',
#  'cafe_count_5000_price_1500',
#  'cafe_count_5000_price_2500',
#  'cafe_count_5000_price_4000',
#  'cafe_count_5000_price_high',
#  'big_church_count_5000',
#  'church_count_5000',
#  'mosque_count_5000',
#  'leisure_count_5000',
#  'sport_count_5000',
#  'market_count_5000']

# %%
len(numerical_cols)
# Out:
# 274

# %%
sub_area_cols = ['sub_area']

# %%
my_cols = categorical_cols + numerical_cols + sub_area_cols

# %%
X_input = X_train_cleaned[my_cols].copy()

# %%
X_input.head()
# Out:
#   product_type culture_objects_top_25 thermal_power_plant_raion  \
# 0   Investment                     no                        no
# 1   Investment                    yes                        no
# 2   Investment                     no                        no
# 3   Investment                     no                        no
# 4   Investment                     no                        no
#
#   incineration_raion oil_chemistry_raion radiation_raion  \
# 0                 no                  no              no
# 1                 no                  no              no
# 2                 no                  no             yes
# 3                 no                  no              no
# 4                 no                  no             yes
#
#   railroad_terminal_raion big_market_raion nuclear_reactor_raion  \
# 0                      no               no                    no
# 1                      no               no                    no
# 2                      no               no                    no
# 3                      no               no                    no
# 4                     yes               no                    no
#
#   detention_facility_raion  ... cafe_count_5000_price_2500  \
# 0                       no  ...                          9
# 1                       no  ...                         15
# 2                       no  ...                         10
# 3                       no  ...                         11
# 4                       no  ...                        319
#
#   cafe_count_5000_price_4000 cafe_count_5000_price_high big_church_count_5000  \
# 0                          4                          0                    13
# 1                          3                          0                    15
# 2                          3                          0                    11
# 3                          2                          1                     4
# 4                        108                         17                   135
#
#    church_count_5000  mosque_count_5000  leisure_count_5000  sport_count_5000  \
# 0                 22                  1                   0                52
# 1                 29                  1                  10                66
# 2                 27                  0                   4                67
# 3                  4                  0                   0                26
# 4                236                  2                  91               195
#
#    market_count_5000           sub_area
# 0                  4           Bibirevo
# 1                 14  Nagatinskij Zaton
# 2                 10     Tekstil'shhiki
# 3                  3             Mitino
# 4                 14          Basmannoe
#
# [5 rows x 289 columns]

# %%
X_input.shape
# Out:
# (30471, 289)

# %% [markdown]
# ## Making pipelines

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
numerical_transformer = SimpleImputer(strategy='median')
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])
sub_area_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('label',OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols),
        ('sub_area', sub_area_transformer, sub_area_cols)
    ])

# %% [markdown]
# ## Define different models

# %%
from sklearn.tree import DecisionTreeRegressor
model1 = DecisionTreeRegressor(random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor(random_state=1)

# %%
from xgboost import XGBRegressor
model3 = XGBRegressor(random_state=1,early_stopping_rounds=5)

# %% [markdown]
# ## Create pipelines

# %%
my_pipeline1 = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', model1),
])

# %%
my_pipeline2 = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', model2),
])

# %%
my_pipeline3 = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', model3),
])

# %% [markdown]
# ## Define X (which feature to use) and y

# %%
top20_features = ['full_sq',
 'sub_area',
 '0_13_female',
 '7_14_female',
 'work_female',
 '0_13_all',
 '0_17_male',
 'young_female',
 '0_17_female',
 'raion_popul',
 '7_14_male',
 '0_13_male',
 'work_male',
 'work_all',
 'young_all',
 '0_17_all',
 'children_school',
 '0_6_female',
 'ekder_female',
 '0_6_male']

# %%
X_input.life_sq
# Out:
# 0        27.0
# 1        19.0
# 2        29.0
# 3        50.0
# 4        77.0
#          ...
# 30466    27.0
# 30467    59.0
# 30468     NaN
# 30469    32.0
# 30470    28.0
# Name: life_sq, Length: 30471, dtype: float64

# %%
X_input[numerical_cols]
# Out:
#        full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# 0           43     27.0    4.0        NaN       NaN         NaN       NaN
# 1           34     19.0    3.0        NaN       NaN         NaN       NaN
# 2           43     29.0    2.0        NaN       NaN         NaN       NaN
# 3           89     50.0    9.0        NaN       NaN         NaN       NaN
# 4           77     77.0    4.0        NaN       NaN         NaN       NaN
# ...        ...      ...    ...        ...       ...         ...       ...
# 30466       44     27.0    7.0        9.0       1.0      1975.0       2.0
# 30467       86     59.0    3.0        9.0       2.0      1935.0       4.0
# 30468       45      NaN   10.0       20.0       1.0         NaN       1.0
# 30469       64     32.0    5.0       15.0       1.0      2003.0       2.0
# 30470       43     28.0    1.0        9.0       1.0      1968.0       2.0
#
#        kitch_sq  state        area_m  ...  cafe_count_5000_price_1500  \
# 0           NaN    NaN  6.407578e+06  ...                          40
# 1           NaN    NaN  9.589337e+06  ...                          36
# 2           NaN    NaN  4.808270e+06  ...                          25
# 3           NaN    NaN  1.258354e+07  ...                          15
# 4           NaN    NaN  8.398461e+06  ...                         552
# ...         ...    ...           ...  ...                         ...
# 30466       6.0    3.0  1.005305e+07  ...                          47
# 30467      10.0    3.0  7.307411e+06  ...                         511
# 30468       1.0    1.0  2.553630e+07  ...                           5
# 30469      11.0    2.0  6.050065e+06  ...                          58
# 30470       6.0    2.0  4.395333e+06  ...                          22
#
#        cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# 0                               9                           4
# 1                              15                           3
# 2                              10                           3
# 3                              11                           2
# 4                             319                         108
# ...                           ...                         ...
# 30466                          15                           5
# 30467                         313                         128
# 30468                           1                           1
# 30469                          22                           1
# 30470                           5                           2
#
#        cafe_count_5000_price_high  big_church_count_5000  church_count_5000  \
# 0                               0                     13                 22
# 1                               0                     15                 29
# 2                               0                     11                 27
# 3                               1                      4                  4
# 4                              17                    135                236
# ...                           ...                    ...                ...
# 30466                           0                     15                 26
# 30467                          24                     98                182
# 30468                           0                      2                 12
# 30469                           1                      6                 31
# 30470                           0                      7                 16
#
#        mosque_count_5000  leisure_count_5000  sport_count_5000  \
# 0                      1                   0                52
# 1                      1                  10                66
# 2                      0                   4                67
# 3                      0                   0                26
# 4                      2                  91               195
# ...                  ...                 ...               ...
# 30466                  1                   2                84
# 30467                  1                  82               171
# 30468                  0                   1                11
# 30469                  1                   4                65
# 30470                  0                   9                54
#
#        market_count_5000
# 0                      4
# 1                     14
# 2                     10
# 3                      3
# 4                     14
# ...                  ...
# 30466                  6
# 30467                 15
# 30468                  1
# 30469                  7
# 30470                 10
#
# [30471 rows x 274 columns]

# %% [markdown]
# ## CV (optinal if with Gridsearch) Test with using ALL features

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid_singletree = {'model__max_leaf_nodes': [50,100,200,500,1000]}

# %%
param_grid_forest = {'model__n_estimators': [50,100,200,500,1000]}

# %%
param_grid_xgboost = {'model__n_estimators': [50,100,200,500,1000],
                     'model__learning_rate': [0.03, 0.05, 0.07, 0.1]
                     }

# %% [markdown]
# ## Single Tree

# %%
grid_search_singletree = GridSearchCV(my_pipeline1, param_grid_singletree, cv=5, scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_singletree.fit(X_input,y)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END ........model__max_leaf_nodes=500;, score=-0.407 total time=   2.9s
# [CV 2/5] END ........model__max_leaf_nodes=500;, score=-0.221 total time=   2.8s
# [CV 3/5] END ........model__max_leaf_nodes=500;, score=-0.283 total time=   2.6s
# [CV 4/5] END ........model__max_leaf_nodes=500;, score=-0.263 total time=   2.7s
# [CV 5/5] END ........model__max_leaf_nodes=500;, score=-0.225 total time=   2.8s
# [CV 1/5] END .......model__max_leaf_nodes=1000;, score=-0.431 total time=   3.0s
# [CV 2/5] END .......model__max_leaf_nodes=1000;, score=-0.266 total time=   3.1s
# [CV 3/5] END .......model__max_leaf_nodes=1000;, score=-0.330 total time=   3.0s
# [CV 4/5] END .......model__max_leaf_nodes=1000;, score=-0.316 total time=   3.0s
# [CV 5/5] END .......model__max_leaf_nodes=1000;, score=-0.280 total time=   3.1s
# [CV 1/5] END .......model__max_leaf_nodes=2000;, score=-0.487 total time=   3.5s
# [CV 2/5] END .......model__max_leaf_nodes=2000;, score=-0.323 total time=   3.5s
# [CV 3/5] END .......model__max_leaf_nodes=2000;, score=-0.388 total time=   3.6s
# [CV 4/5] END .......model__max_leaf_nodes=2000;, score=-0.378 total time=   3.6s
# [CV 5/5] END .......model__max_leaf_nodes=2000;, score=-0.329 total time=   3.9s
# [CV 1/5] END .......model__max_leaf_nodes=5000;, score=-0.526 total time=   3.8s
# [CV 2/5] END .......model__max_leaf_nodes=5000;, score=-0.375 total time=   4.1s
# [CV 3/5] END .......model__max_leaf_nodes=5000;, score=-0.451 total time=   4.1s
# [CV 4/5] END .......model__max_leaf_nodes=5000;, score=-0.430 total time=   3.8s
# [CV 5/5] END .......model__max_leaf_nodes=5000;, score=-0.370 total time=   4.0s
# [CV 1/5] END ......model__max_leaf_nodes=10000;, score=-0.532 total time=   4.2s
# [CV 2/5] END ......model__max_leaf_nodes=10000;, score=-0.391 total time=   4.2s
# [CV 3/5] END ......model__max_leaf_nodes=10000;, score=-0.472 total time=   4.0s
# [CV 4/5] END ......model__max_leaf_nodes=10000;, score=-0.446 total time=   4.0s
# [CV 5/5] END ......model__max_leaf_nodes=10000;, score=-0.382 total time=   4.4s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          ['full_sq',
#                                                                           'life_sq',
#                                                                           'floor',
#                                                                           'max_floor',
#                                                                           'material',
#                                                                           'build_year',
#                                                                           'num_room',
#                                                                           'kitch_sq',
#                                                                           'state',
#                                                                           'area_m',
#                                                                           'raion_popul',
#                                                                           'green_zone_part',
#                                                                           'indust_part',
#                                                                           'children_preschool',
#                                                                           'preschool_quota',
#                                                                           'preschool_education_centers_...
#                                                                           'ecology']),
#                                                                         ('sub_area',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('label',
#                                                                                           OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                                          unknown_value=-1))]),
#                                                                          ['sub_area'])])),
#                                        ('model',
#                                         DecisionTreeRegressor(random_state=1))]),
#              param_grid={'model__max_leaf_nodes': [500, 1000, 2000, 5000,
#                                                    10000]},
#              scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_singletree.best_params_
# Out:
# {'model__max_leaf_nodes': 500}

# %%
grid_search_singletree.best_score_
# Out:
# -0.27990865753610483

# %%
grid_search_singletree1 = GridSearchCV(my_pipeline1, param_grid_singletree1, cv=5, scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_singletree1.fit(X_input,y)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END .........model__max_leaf_nodes=50;, score=-0.396 total time=   2.1s
# [CV 2/5] END .........model__max_leaf_nodes=50;, score=-0.211 total time=   2.1s
# [CV 3/5] END .........model__max_leaf_nodes=50;, score=-0.247 total time=   2.3s
# [CV 4/5] END .........model__max_leaf_nodes=50;, score=-0.235 total time=   2.1s
# [CV 5/5] END .........model__max_leaf_nodes=50;, score=-0.206 total time=   2.3s
# [CV 1/5] END ........model__max_leaf_nodes=100;, score=-0.392 total time=   2.3s
# [CV 2/5] END ........model__max_leaf_nodes=100;, score=-0.202 total time=   2.2s
# [CV 3/5] END ........model__max_leaf_nodes=100;, score=-0.243 total time=   2.9s
# [CV 4/5] END ........model__max_leaf_nodes=100;, score=-0.226 total time=   2.7s
# [CV 5/5] END ........model__max_leaf_nodes=100;, score=-0.198 total time=   2.8s
# [CV 1/5] END ........model__max_leaf_nodes=200;, score=-0.395 total time=   2.9s
# [CV 2/5] END ........model__max_leaf_nodes=200;, score=-0.205 total time=   2.7s
# [CV 3/5] END ........model__max_leaf_nodes=200;, score=-0.254 total time=   2.4s
# [CV 4/5] END ........model__max_leaf_nodes=200;, score=-0.234 total time=   2.4s
# [CV 5/5] END ........model__max_leaf_nodes=200;, score=-0.200 total time=   2.6s
# [CV 1/5] END ........model__max_leaf_nodes=500;, score=-0.407 total time=   2.8s
# [CV 2/5] END ........model__max_leaf_nodes=500;, score=-0.221 total time=   3.2s
# [CV 3/5] END ........model__max_leaf_nodes=500;, score=-0.283 total time=   3.1s
# [CV 4/5] END ........model__max_leaf_nodes=500;, score=-0.263 total time=   2.9s
# [CV 5/5] END ........model__max_leaf_nodes=500;, score=-0.225 total time=   3.1s
# [CV 1/5] END .......model__max_leaf_nodes=1000;, score=-0.431 total time=   3.1s
# [CV 2/5] END .......model__max_leaf_nodes=1000;, score=-0.266 total time=   3.3s
# [CV 3/5] END .......model__max_leaf_nodes=1000;, score=-0.330 total time=   3.3s
# [CV 4/5] END .......model__max_leaf_nodes=1000;, score=-0.316 total time=   3.1s
# [CV 5/5] END .......model__max_leaf_nodes=1000;, score=-0.280 total time=   3.9s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          ['full_sq',
#                                                                           'life_sq',
#                                                                           'floor',
#                                                                           'max_floor',
#                                                                           'material',
#                                                                           'build_year',
#                                                                           'num_room',
#                                                                           'kitch_sq',
#                                                                           'state',
#                                                                           'area_m',
#                                                                           'raion_popul',
#                                                                           'green_zone_part',
#                                                                           'indust_part',
#                                                                           'children_preschool',
#                                                                           'preschool_quota',
#                                                                           'preschool_education_centers_...
#                                                                           'railroad_1line',
#                                                                           'ecology']),
#                                                                         ('sub_area',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('label',
#                                                                                           OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                                          unknown_value=-1))]),
#                                                                          ['sub_area'])])),
#                                        ('model',
#                                         DecisionTreeRegressor(random_state=1))]),
#              param_grid={'model__max_leaf_nodes': [50, 100, 200, 500, 1000]},
#              scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_singletree1.best_params_
# Out:
# {'model__max_leaf_nodes': 100}

# %%
grid_search_singletree1.best_score_
# Out:
# -0.2523952264512714

# %% [markdown]
# ## XGBOOST

# %%
grid_search_xgboost = GridSearchCV(my_pipeline3, param_grid_xgboost, cv=5, scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_xgboost.fit(X_input,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [05:09:42] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.323 total time=   3.8s
# [05:09:46] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.206 total time=   4.0s
# [05:09:50] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.253 total time=   3.9s
# [05:09:54] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.248 total time=   3.9s
# [05:09:58] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.254 total time=   3.8s
# [05:10:02] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.354 total time=   6.7s
# [05:10:09] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.184 total time=   7.3s
# [05:10:16] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.223 total time=   8.1s
# [05:10:24] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.204 total time=   7.8s
# [05:10:32] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.181 total time=   8.1s
# [05:10:41] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.363 total time=  14.1s
# [05:10:55] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.186 total time=  14.3s
# [05:11:09] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.226 total time=  14.1s
# [05:11:23] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.202 total time=  15.4s
# [05:11:39] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.172 total time=  14.9s
# [05:11:54] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.359 total time=  32.8s
# [05:12:27] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.184 total time=  32.7s
# [05:13:00] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.225 total time=  35.6s
# [05:13:35] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.200 total time=  34.7s
# [05:14:10] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.169 total time=  33.6s
# [05:14:44] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.357 total time= 1.1min
# [05:15:47] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.185 total time= 1.1min
# [05:16:53] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.226 total time= 1.1min
# [05:18:00] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.199 total time= 1.1min
# [05:19:05] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.170 total time= 1.1min
# [05:20:11] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.345 total time=   4.5s
# [05:20:16] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.183 total time=   4.7s
# [05:20:20] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.223 total time=   4.2s
# [05:20:25] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.207 total time=   4.3s
# [05:20:29] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.188 total time=   4.1s
# [05:20:34] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.363 total time=   8.2s
# [05:20:42] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.186 total time=   8.2s
# [05:20:50] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.226 total time=   7.4s
# [05:20:58] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.203 total time=   7.9s
# [05:21:06] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.172 total time=   7.8s
# [05:21:14] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.361 total time=  14.0s
# [05:21:28] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.185 total time=  14.9s
# [05:21:43] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.226 total time=  14.2s
# [05:21:57] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.200 total time=  13.6s
# [05:22:11] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.169 total time=  13.6s
# [05:22:25] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.358 total time=  33.3s
# [05:22:58] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.184 total time=  34.9s
# [05:23:33] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.225 total time=  31.2s
# [05:24:04] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.200 total time=  32.7s
# [05:24:37] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.170 total time=  34.3s
# [05:25:11] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.359 total time= 1.1min
# [05:26:18] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.188 total time= 1.1min
# [05:27:21] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.228 total time= 1.1min
# [05:28:26] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.203 total time= 1.0min
# [05:29:29] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.172 total time= 1.0min
# [05:30:31] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.360 total time=   4.0s
# [05:30:35] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.185 total time=   4.1s
# [05:30:40] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.225 total time=   4.0s
# [05:30:44] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.203 total time=   4.1s
# [05:30:48] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.178 total time=   4.0s
# [05:30:52] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.363 total time=   7.1s
# [05:30:59] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.185 total time=   7.2s
# [05:31:07] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.226 total time=   7.2s
# [05:31:14] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.202 total time=   7.1s
# [05:31:21] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.172 total time=   7.1s
# [05:31:28] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.360 total time=  13.0s
# [05:31:42] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.184 total time=  13.3s
# [05:31:55] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.226 total time=  13.2s
# [05:32:08] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.201 total time=  13.7s
# [05:32:22] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.170 total time=  14.4s
# [05:32:37] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.359 total time=  30.8s
# [05:33:07] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.186 total time=  31.6s
# [05:33:39] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.228 total time=  31.1s
# [05:34:10] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.202 total time=  32.7s
# [05:34:43] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.172 total time=  36.4s
# [05:35:20] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.362 total time= 1.1min
# [05:36:26] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.193 total time= 1.1min
# [05:37:32] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.233 total time= 1.1min
# [05:38:36] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.206 total time= 1.1min
# [05:39:39] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=nan total time= 1.1min
# [05:40:43] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.363 total time=   4.2s
# [05:40:48] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.187 total time=   4.1s
# [05:40:52] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.226 total time=   4.0s
# [05:40:56] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.203 total time=   4.1s
# [05:41:00] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.173 total time=   4.1s
# [05:41:04] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.360 total time=   7.4s
# [05:41:12] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.185 total time=   7.2s
# [05:41:19] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.226 total time=   7.0s
# [05:41:26] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.201 total time=   7.2s
# [05:41:34] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.170 total time=   7.0s
# [05:41:41] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.358 total time=  13.0s
# [05:41:54] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.185 total time=  13.6s
# [05:42:08] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.226 total time=  13.2s
# [05:42:21] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.200 total time=  13.5s
# [05:42:35] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.170 total time=  13.3s
# [05:42:48] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.359 total time=  31.7s
# [05:43:20] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=500;, score=nan total time=  32.3s
# [05:43:52] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.230 total time=  31.8s
# [05:44:24] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.203 total time=  33.4s
# [05:44:58] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.173 total time=  32.1s
# [05:45:30] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.365 total time= 1.1min
# [05:46:37] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=nan total time= 1.1min
# [05:47:43] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=nan total time= 1.1min
# [05:48:47] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=nan total time= 1.1min
# [05:49:53] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.183 total time= 1.1min
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [-0.25662224 -0.22903643 -0.22980492 -0.22735653 -0.22752521 -0.22891589
#  -0.23018529 -0.22827482 -0.22744477 -0.23009292 -0.23029246 -0.22949877
#  -0.22791407 -0.22937756         nan -0.23037987 -0.22820583 -0.22768867
#          nan         nan]
#   warnings.warn(
# [05:50:59] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          ['full_sq',
#                                                                           'life_sq',
#                                                                           'floor',
#                                                                           'max_floor',
#                                                                           'material',
#                                                                           'build_year',
#                                                                           'num_room',
#                                                                           'kitch_sq',
#                                                                           'state',
#                                                                           'area_m',
#                                                                           'raion_popul',
#                                                                           'green_zone_part',
#                                                                           'indust_part',
#                                                                           'children_preschool',
#                                                                           'preschool_quota',
#                                                                           'preschool_education_centers_...
#                                                      n_estimators=100,
#                                                      n_jobs=None,
#                                                      num_parallel_tree=None,
#                                                      predictor=None,
#                                                      random_state=1,
#                                                      reg_alpha=None,
#                                                      reg_lambda=None,
#                                                      scale_pos_weight=None,
#                                                      subsample=None,
#                                                      tree_method=None,
#                                                      validate_parameters=None,
#                                                      verbosity=None))]),
#              param_grid={'model__learning_rate': [0.03, 0.05, 0.07, 0.1],
#                          'model__n_estimators': [50, 100, 200, 500, 1000]},
#              scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_xgboost.best_params_
# Out:
# {'model__learning_rate': 0.03, 'model__n_estimators': 500}

# %%
grid_search_xgboost.best_score_
# Out:
# -0.22735653350547108

# %%
scores1 = -1 * cross_val_score(my_pipeline1, X_input, y, cv=5, scoring='neg_mean_squared_log_error')

# %%
scores1
# Out:
# array([0.54551017, 0.39776924, 0.4633882 , 0.43634591, 0.3883457 ])

# %%
scores1.mean()
# Out:
# 0.44627184477970977

# %%
scores2 = -1 * cross_val_score(my_pipeline2, X_input, y, cv=5, scoring='neg_mean_squared_log_error')

# %%
scores2
# Out:
# array([0.36738411, 0.18748647, 0.22842122, 0.20547225, 0.17551595])

# %%
scores2.mean()
# Out:
# 0.23285599846584373

# %%
scores3 = -1 * cross_val_score(my_pipeline3, X_input, y, cv=5, scoring='neg_mean_squared_log_error')

# %%
scores3

# %%
scores3.mean()

# %% [markdown]
# ## CV (optinal if with Gridsearch) Test with using TOP 20 features

# %%
grid_search_singletree_top = GridSearchCV(my_pipeline1_top, param_grid_singletree1, cv=5, scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_singletree_top.fit(X_top20,y)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END .........model__max_leaf_nodes=50;, score=-0.405 total time=   0.0s
# [CV 2/5] END .........model__max_leaf_nodes=50;, score=-0.213 total time=   0.0s
# [CV 3/5] END .........model__max_leaf_nodes=50;, score=-0.257 total time=   0.0s
# [CV 4/5] END .........model__max_leaf_nodes=50;, score=-0.241 total time=   0.0s
# [CV 5/5] END .........model__max_leaf_nodes=50;, score=-0.220 total time=   0.0s
# [CV 1/5] END ........model__max_leaf_nodes=100;, score=-0.399 total time=   0.0s
# [CV 2/5] END ........model__max_leaf_nodes=100;, score=-0.209 total time=   0.0s
# [CV 3/5] END ........model__max_leaf_nodes=100;, score=-0.249 total time=   0.0s
# [CV 4/5] END ........model__max_leaf_nodes=100;, score=-0.238 total time=   0.0s
# [CV 5/5] END ........model__max_leaf_nodes=100;, score=-0.213 total time=   0.0s
# [CV 1/5] END ........model__max_leaf_nodes=200;, score=-0.397 total time=   0.0s
# [CV 2/5] END ........model__max_leaf_nodes=200;, score=-0.206 total time=   0.0s
# [CV 3/5] END ........model__max_leaf_nodes=200;, score=-0.247 total time=   0.0s
# [CV 4/5] END ........model__max_leaf_nodes=200;, score=-0.236 total time=   0.0s
# [CV 5/5] END ........model__max_leaf_nodes=200;, score=-0.212 total time=   0.0s
# [CV 1/5] END ........model__max_leaf_nodes=500;, score=-0.399 total time=   0.0s
# [CV 2/5] END ........model__max_leaf_nodes=500;, score=-0.217 total time=   0.0s
# [CV 3/5] END ........model__max_leaf_nodes=500;, score=-0.255 total time=   0.0s
# [CV 4/5] END ........model__max_leaf_nodes=500;, score=-0.239 total time=   0.0s
# [CV 5/5] END ........model__max_leaf_nodes=500;, score=-0.217 total time=   0.0s
# [CV 1/5] END .......model__max_leaf_nodes=1000;, score=-0.414 total time=   0.0s
# [CV 2/5] END .......model__max_leaf_nodes=1000;, score=-0.222 total time=   0.0s
# [CV 3/5] END .......model__max_leaf_nodes=1000;, score=-0.276 total time=   0.0s
# [CV 4/5] END .......model__max_leaf_nodes=1000;, score=-0.258 total time=   0.0s
# [CV 5/5] END .......model__max_leaf_nodes=1000;, score=-0.221 total time=   0.0s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          ['full_sq',
#                                                                           '0_13_female',
#                                                                           '7_14_female',
#                                                                           'work_female',
#                                                                           '0_13_all',
#                                                                           '0_17_male',
#                                                                           'young_female',
#                                                                           '0_17_female',
#                                                                           'raion_popul',
#                                                                           '7_14_male',
#                                                                           '0_13_male',
#                                                                           'work_male',
#                                                                           'work_all',
#                                                                           'young_all',
#                                                                           '0_17_all',
#                                                                           'children_school',
#                                                                           '0_6_female',
#                                                                           'ekder_female',
#                                                                           '0_6_male']),
#                                                                         ('sub_area',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('label',
#                                                                                           OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                                          unknown_value=-1))]),
#                                                                          ['sub_area'])])),
#                                        ('model',
#                                         DecisionTreeRegressor(random_state=1))]),
#              param_grid={'model__max_leaf_nodes': [50, 100, 200, 500, 1000]},
#              scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_singletree_top.best_params_
# Out:
# {'model__max_leaf_nodes': 200}

# %%
grid_search_singletree_top.best_score_
# Out:
# -0.2595431817723153

# %% [markdown]
# ## Forest

# %%
grid_search_forest_top = GridSearchCV(my_pipeline2_top, param_grid_forest, cv=5, scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_forest_top.fit(X_top20,y)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END ...........model__n_estimators=50;, score=-0.410 total time=   3.6s
# [CV 2/5] END ...........model__n_estimators=50;, score=-0.216 total time=   3.8s
# [CV 3/5] END ...........model__n_estimators=50;, score=-0.257 total time=   3.9s
# [CV 4/5] END ...........model__n_estimators=50;, score=-0.237 total time=   4.3s
# [CV 5/5] END ...........model__n_estimators=50;, score=-0.209 total time=   3.8s
# [CV 1/5] END ..........model__n_estimators=100;, score=-0.409 total time=   8.0s
# [CV 2/5] END ..........model__n_estimators=100;, score=-0.215 total time=   7.9s
# [CV 3/5] END ..........model__n_estimators=100;, score=-0.256 total time=   7.7s
# [CV 4/5] END ..........model__n_estimators=100;, score=-0.237 total time=   7.3s
# [CV 5/5] END ..........model__n_estimators=100;, score=-0.209 total time=   7.7s
# [CV 1/5] END ..........model__n_estimators=200;, score=-0.408 total time=  15.5s
# [CV 2/5] END ..........model__n_estimators=200;, score=-0.215 total time=  14.6s
# [CV 3/5] END ..........model__n_estimators=200;, score=-0.255 total time=  14.5s
# [CV 4/5] END ..........model__n_estimators=200;, score=-0.236 total time=  15.9s
# [CV 5/5] END ..........model__n_estimators=200;, score=-0.208 total time=  15.2s
# [CV 1/5] END ..........model__n_estimators=500;, score=-0.408 total time=  38.2s
# [CV 2/5] END ..........model__n_estimators=500;, score=-0.214 total time=  40.4s
# [CV 3/5] END ..........model__n_estimators=500;, score=-0.255 total time=  39.5s
# [CV 4/5] END ..........model__n_estimators=500;, score=-0.236 total time=  41.2s
# [CV 5/5] END ..........model__n_estimators=500;, score=-0.208 total time=  41.6s
# [CV 1/5] END .........model__n_estimators=1000;, score=-0.408 total time= 1.3min
# [CV 2/5] END .........model__n_estimators=1000;, score=-0.215 total time= 1.3min
# [CV 3/5] END .........model__n_estimators=1000;, score=-0.255 total time= 1.4min
# [CV 4/5] END .........model__n_estimators=1000;, score=-0.236 total time= 1.3min
# [CV 5/5] END .........model__n_estimators=1000;, score=-0.208 total time= 1.3min
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          ['full_sq',
#                                                                           '0_13_female',
#                                                                           '7_14_female',
#                                                                           'work_female',
#                                                                           '0_13_all',
#                                                                           '0_17_male',
#                                                                           'young_female',
#                                                                           '0_17_female',
#                                                                           'raion_popul',
#                                                                           '7_14_male',
#                                                                           '0_13_male',
#                                                                           'work_male',
#                                                                           'work_all',
#                                                                           'young_all',
#                                                                           '0_17_all',
#                                                                           'children_school',
#                                                                           '0_6_female',
#                                                                           'ekder_female',
#                                                                           '0_6_male']),
#                                                                         ('sub_area',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('label',
#                                                                                           OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                                          unknown_value=-1))]),
#                                                                          ['sub_area'])])),
#                                        ('model',
#                                         RandomForestRegressor(random_state=1))]),
#              param_grid={'model__n_estimators': [50, 100, 200, 500, 1000]},
#              scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_forest_top.best_params_
# Out:
# {'model__n_estimators': 500}

# %%
grid_search_forest_top.best_score_
# Out:
# -0.2643936040745176

# %% [markdown]
# ## XGBOOST

# %%
grid_search_xgboost_top = GridSearchCV(my_pipeline3_top, param_grid_xgboost, cv=5, scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_xgboost_top.fit(X_top20,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.328 total time=   0.3s
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.210 total time=   0.3s
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.266 total time=   0.3s
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.267 total time=   0.3s
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.276 total time=   0.3s
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.367 total time=   0.6s
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.192 total time=   0.6s
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.232 total time=   0.6s
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.218 total time=   0.6s
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.200 total time=   0.6s
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.386 total time=   1.1s
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.198 total time=   1.1s
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.233 total time=   1.1s
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.215 total time=   1.1s
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.190 total time=   1.1s
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.387 total time=   2.5s
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.199 total time=   2.5s
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.232 total time=   2.5s
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.214 total time=   2.4s
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.188 total time=   2.6s
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.388 total time=   5.4s
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.211 total time=   5.1s
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.233 total time=   5.3s
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.215 total time=   5.8s
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.190 total time=   5.6s
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.356 total time=   0.3s
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.190 total time=   0.3s
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.233 total time=   0.4s
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.221 total time=   0.4s
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.207 total time=   0.3s
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.384 total time=   0.7s
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.198 total time=   0.7s
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.234 total time=   0.7s
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.215 total time=   0.7s
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.191 total time=   0.7s
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.387 total time=   1.2s
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.199 total time=   1.1s
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.233 total time=   1.2s
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.214 total time=   1.2s
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.188 total time=   1.2s
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.388 total time=   2.7s
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.200 total time=   2.7s
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.233 total time=   2.8s
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.215 total time=   3.2s
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.189 total time=   2.9s
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.391 total time=   5.7s
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.202 total time=   5.6s
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.236 total time=   5.4s
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.219 total time=   5.5s
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.192 total time=   5.4s
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.375 total time=   0.3s
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.195 total time=   0.3s
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.233 total time=   0.3s
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.217 total time=   0.3s
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.196 total time=   0.3s
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.386 total time=   0.6s
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.199 total time=   0.6s
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.234 total time=   0.6s
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.214 total time=   0.6s
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.189 total time=   0.7s
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.387 total time=   1.2s
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.198 total time=   1.2s
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.233 total time=   1.2s
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.213 total time=   1.1s
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.188 total time=   1.3s
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.389 total time=   2.7s
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.199 total time=   2.9s
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.235 total time=   2.7s
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.216 total time=   2.8s
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.191 total time=   2.7s
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.394 total time=   5.5s
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.203 total time=   5.7s
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.242 total time=   5.7s
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.223 total time=   5.5s
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.196 total time=   5.6s
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.384 total time=   0.3s
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.198 total time=   0.3s
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.233 total time=   0.3s
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.216 total time=   0.3s
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.191 total time=   0.3s
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.386 total time=   0.7s
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.199 total time=   0.6s
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.233 total time=   0.6s
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.214 total time=   0.6s
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.187 total time=   0.6s
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.387 total time=   1.2s
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.199 total time=   1.2s
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.233 total time=   1.2s
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.214 total time=   1.2s
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.189 total time=   1.1s
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.391 total time=   2.8s
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.202 total time=   3.0s
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.237 total time=   2.8s
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.219 total time=   2.8s
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.192 total time=   2.7s
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.398 total time=   5.4s
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.207 total time=   5.5s
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.247 total time=   5.6s
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.230 total time=   5.8s
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.199 total time=   5.6s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          ['full_sq',
#                                                                           '0_13_female',
#                                                                           '7_14_female',
#                                                                           'work_female',
#                                                                           '0_13_all',
#                                                                           '0_17_male',
#                                                                           'young_female',
#                                                                           '0_17_female',
#                                                                           'raion_popul',
#                                                                           '7_14_male',
#                                                                           '0_13_male',
#                                                                           'work_male',
#                                                                           'work_all',
#                                                                           'young_all',
#                                                                           '0_17_all',
#                                                                           'children_school',
#                                                                           '0_6_female...
#                                                      n_estimators=100,
#                                                      n_jobs=None,
#                                                      num_parallel_tree=None,
#                                                      predictor=None,
#                                                      random_state=1,
#                                                      reg_alpha=None,
#                                                      reg_lambda=None,
#                                                      scale_pos_weight=None,
#                                                      subsample=None,
#                                                      tree_method=None,
#                                                      validate_parameters=None,
#                                                      verbosity=None))]),
#              param_grid={'model__learning_rate': [0.03, 0.05, 0.07, 0.1],
#                          'model__n_estimators': [50, 100, 200, 500, 1000]},
#              scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_xgboost_top.best_params_
# Out:
# {'model__learning_rate': 0.05, 'model__n_estimators': 50}

# %%
grid_search_xgboost_top.best_score_
# Out:
# -0.24127230112717807

# %% [markdown]
# ## -----------------------

# %%
X_top20 = X_input[top20_features]

# %%
X_top20.dtypes
# Out:
# full_sq             int64
# sub_area           object
# 0_13_female         int64
# 7_14_female         int64
# work_female         int64
# 0_13_all            int64
# 0_17_male           int64
# young_female        int64
# 0_17_female         int64
# raion_popul         int64
# 7_14_male           int64
# 0_13_male           int64
# work_male           int64
# work_all            int64
# young_all           int64
# 0_17_all            int64
# children_school     int64
# 0_6_female          int64
# ekder_female        int64
# 0_6_male            int64
# dtype: object

# %%
X_top20.columns
# Out:
# Index(['full_sq', 'sub_area', '0_13_female', '7_14_female', 'work_female',
#        '0_13_all', '0_17_male', 'young_female', '0_17_female', 'raion_popul',
#        '7_14_male', '0_13_male', 'work_male', 'work_all', 'young_all',
#        '0_17_all', 'children_school', '0_6_female', 'ekder_female',
#        '0_6_male'],
#       dtype='object')

# %%
numerical_cols_top = ['full_sq', '0_13_female', '7_14_female', 'work_female',
       '0_13_all', '0_17_male', 'young_female', '0_17_female', 'raion_popul',
       '7_14_male', '0_13_male', 'work_male', 'work_all', 'young_all',
       '0_17_all', 'children_school', '0_6_female', 'ekder_female',
       '0_6_male']

# %%
categorical_cols_top = ['sub_area']

# %%
preprocessor_top = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols_top),
        ('sub_area', sub_area_transformer, categorical_cols_top)
    ])

# %%
my_pipeline1_top = Pipeline(steps=[
    ('preprocessor', preprocessor_top),
    ('model', model1),
])

# %%
my_pipeline2_top = Pipeline(steps=[
    ('preprocessor', preprocessor_top),
    ('model', model2),
])

# %%
my_pipeline3_top = Pipeline(steps=[
    ('preprocessor', preprocessor_top),
    ('model', model3),
])

# %%
scores1_top = -1 * cross_val_score(my_pipeline1_top, X_top20, y, cv=5, scoring='neg_mean_squared_log_error')

# %%
scores1_top
# Out:
# array([0.45992925, 0.26243839, 0.32562733, 0.29701708, 0.28431644])

# %%
scores1_top.mean()
# Out:
# 0.32586569728342923

# %%
scores2_top = -1 * cross_val_score(my_pipeline2_top, X_top20, y, cv=5, scoring='neg_mean_squared_log_error')

# %%
scores2_top
# Out:
# array([0.40865489, 0.21502985, 0.25586191, 0.23659428, 0.20882305])

# %%
scores2_top.mean()
# Out:
# 0.2649927968627222

# %%
scores3_top = -1 * cross_val_score(my_pipeline3_top, X_top20, y, cv=5, scoring='neg_mean_squared_log_error')

# %%
scores3_top
# Out:
# array([0.39041806, 0.20032383, 0.23472604, 0.21634221, 0.19235673])

# %%
scores3_top.mean()
# Out:
# 0.24683337327024088

# %% [markdown]
# ## CV (optinal if with Gridsearch) Test with using Random 20 features

# %%
grid_search_singletree_random = GridSearchCV(my_pipeline1_random, param_grid_singletree1, cv=5, scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_singletree_random.fit(X_random20,y)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END .........model__max_leaf_nodes=50;, score=-0.433 total time=   0.1s
# [CV 2/5] END .........model__max_leaf_nodes=50;, score=-0.257 total time=   0.0s
# [CV 3/5] END .........model__max_leaf_nodes=50;, score=-0.269 total time=   0.0s
# [CV 4/5] END .........model__max_leaf_nodes=50;, score=-0.269 total time=   0.0s
# [CV 5/5] END .........model__max_leaf_nodes=50;, score=-0.240 total time=   0.0s
# [CV 1/5] END ........model__max_leaf_nodes=100;, score=-0.424 total time=   0.0s
# [CV 2/5] END ........model__max_leaf_nodes=100;, score=-0.249 total time=   0.0s
# [CV 3/5] END ........model__max_leaf_nodes=100;, score=-0.264 total time=   0.0s
# [CV 4/5] END ........model__max_leaf_nodes=100;, score=-0.265 total time=   0.0s
# [CV 5/5] END ........model__max_leaf_nodes=100;, score=-0.236 total time=   0.0s
# [CV 1/5] END ........model__max_leaf_nodes=200;, score=-0.426 total time=   0.0s
# [CV 2/5] END ........model__max_leaf_nodes=200;, score=-0.242 total time=   0.1s
# [CV 3/5] END ........model__max_leaf_nodes=200;, score=-0.257 total time=   0.1s
# [CV 4/5] END ........model__max_leaf_nodes=200;, score=-0.258 total time=   0.1s
# [CV 5/5] END ........model__max_leaf_nodes=200;, score=-0.229 total time=   0.1s
# [CV 1/5] END ........model__max_leaf_nodes=500;, score=-0.439 total time=   0.1s
# [CV 2/5] END ........model__max_leaf_nodes=500;, score=-0.244 total time=   0.1s
# [CV 3/5] END ........model__max_leaf_nodes=500;, score=-0.275 total time=   0.1s
# [CV 4/5] END ........model__max_leaf_nodes=500;, score=-0.275 total time=   0.1s
# [CV 5/5] END ........model__max_leaf_nodes=500;, score=-0.251 total time=   0.1s
# [CV 1/5] END .......model__max_leaf_nodes=1000;, score=-0.451 total time=   0.1s
# [CV 2/5] END .......model__max_leaf_nodes=1000;, score=-0.265 total time=   0.1s
# [CV 3/5] END .......model__max_leaf_nodes=1000;, score=-0.313 total time=   0.1s
# [CV 4/5] END .......model__max_leaf_nodes=1000;, score=-0.311 total time=   0.2s
# [CV 5/5] END .......model__max_leaf_nodes=1000;, score=-0.286 total time=   0.1s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          ['life_sq',
#                                                                           'children_school',
#                                                                           'young_all',
#                                                                           '0_17_all',
#                                                                           'build_count_panel',
#                                                                           'kindergarten_km',
#                                                                           'public_transport_station_min_walk',
#                                                                           'ID_bus_terminal',
#                                                                           'detention_facility_km',
#                                                                           'green_part_500',
#                                                                           'cafe_count_500_price_4000',
#                                                                           'cafe...
#                                                                           'cafe_count_3000_price_1500',
#                                                                           'trc_sqm_5000',
#                                                                           'leisure_count_5000']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['product_type'])])),
#                                        ('model',
#                                         DecisionTreeRegressor(random_state=1))]),
#              param_grid={'model__max_leaf_nodes': [50, 100, 200, 500, 1000]},
#              scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_singletree_random.best_params_
# Out:
# {'model__max_leaf_nodes': 200}

# %%
grid_search_singletree_random.best_score_
# Out:
# -0.28235788141400453

# %% [markdown]
# ## Forest

# %%
grid_search_forest_random = GridSearchCV(my_pipeline2_random, param_grid_forest, cv=5, scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_forest_random.fit(X_random20,y)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END ...........model__n_estimators=50;, score=-0.404 total time=   6.8s
# [CV 2/5] END ...........model__n_estimators=50;, score=-0.233 total time=   7.5s
# [CV 3/5] END ...........model__n_estimators=50;, score=-0.252 total time=   7.3s
# [CV 4/5] END ...........model__n_estimators=50;, score=-0.244 total time=   9.0s
# [CV 5/5] END ...........model__n_estimators=50;, score=-0.210 total time=   8.6s
# [CV 1/5] END ..........model__n_estimators=100;, score=-0.403 total time=  14.2s
# [CV 2/5] END ..........model__n_estimators=100;, score=-0.231 total time=  14.2s
# [CV 3/5] END ..........model__n_estimators=100;, score=-0.251 total time=  13.7s
# [CV 4/5] END ..........model__n_estimators=100;, score=-0.244 total time=  15.8s
# [CV 5/5] END ..........model__n_estimators=100;, score=-0.209 total time=  15.8s
# [CV 1/5] END ..........model__n_estimators=200;, score=-0.402 total time=  27.1s
# [CV 2/5] END ..........model__n_estimators=200;, score=-0.231 total time=  28.9s
# [CV 3/5] END ..........model__n_estimators=200;, score=-0.250 total time=  27.9s
# [CV 4/5] END ..........model__n_estimators=200;, score=-0.243 total time=  28.4s
# [CV 5/5] END ..........model__n_estimators=200;, score=-0.208 total time=  28.9s
# [CV 1/5] END ..........model__n_estimators=500;, score=-0.402 total time= 1.2min
# [CV 2/5] END ..........model__n_estimators=500;, score=-0.230 total time= 1.2min
# [CV 3/5] END ..........model__n_estimators=500;, score=-0.249 total time= 1.2min
# [CV 4/5] END ..........model__n_estimators=500;, score=-0.242 total time= 1.2min
# [CV 5/5] END ..........model__n_estimators=500;, score=-0.207 total time= 1.2min
# [CV 1/5] END .........model__n_estimators=1000;, score=-0.402 total time= 2.5min
# [CV 2/5] END .........model__n_estimators=1000;, score=-0.231 total time= 2.6min
# [CV 3/5] END .........model__n_estimators=1000;, score=-0.249 total time= 2.3min
# [CV 4/5] END .........model__n_estimators=1000;, score=-0.242 total time= 2.3min
# [CV 5/5] END .........model__n_estimators=1000;, score=-0.207 total time= 2.4min
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          ['life_sq',
#                                                                           'children_school',
#                                                                           'young_all',
#                                                                           '0_17_all',
#                                                                           'build_count_panel',
#                                                                           'kindergarten_km',
#                                                                           'public_transport_station_min_walk',
#                                                                           'ID_bus_terminal',
#                                                                           'detention_facility_km',
#                                                                           'green_part_500',
#                                                                           'cafe_count_500_price_4000',
#                                                                           'cafe...
#                                                                           'cafe_count_3000_price_1500',
#                                                                           'trc_sqm_5000',
#                                                                           'leisure_count_5000']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['product_type'])])),
#                                        ('model',
#                                         RandomForestRegressor(random_state=1))]),
#              param_grid={'model__n_estimators': [50, 100, 200, 500, 1000]},
#              scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_forest_random.best_params_
# Out:
# {'model__n_estimators': 1000}

# %%
grid_search_forest_random.best_score_
# Out:
# -0.26635835485187015

# %% [markdown]
# ## XGBOOST

# %%
grid_search_xgboost_random = GridSearchCV(my_pipeline3_random, param_grid_xgboost, cv=5, scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_xgboost_random.fit(X_random20,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.344 total time=   0.5s
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.229 total time=   0.5s
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.275 total time=   0.5s
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.283 total time=   0.4s
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.289 total time=   0.5s
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.388 total time=   0.9s
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.224 total time=   0.9s
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.244 total time=   0.9s
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.239 total time=   0.9s
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.215 total time=   0.9s
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.407 total time=   1.6s
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.232 total time=   1.9s
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.246 total time=   1.9s
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.237 total time=   1.7s
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.207 total time=   1.7s
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.404 total time=   4.1s
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.229 total time=   4.5s
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.245 total time=   4.1s
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.235 total time=   4.3s
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.205 total time=   4.4s
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.403 total time=   8.8s
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.227 total time=   9.4s
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.247 total time=   9.4s
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.234 total time=   9.3s
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.206 total time=   8.9s
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.377 total time=   0.5s
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.220 total time=   0.5s
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.244 total time=   0.5s
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.241 total time=   0.5s
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.222 total time=   0.5s
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.406 total time=   1.0s
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.233 total time=   1.0s
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.247 total time=   1.0s
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.238 total time=   0.9s
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.208 total time=   1.1s
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.407 total time=   1.8s
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.232 total time=   1.9s
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.246 total time=   2.0s
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.236 total time=   2.0s
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.205 total time=   1.9s
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.404 total time=   5.2s
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.229 total time=   5.0s
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.245 total time=   4.5s
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.233 total time=   4.5s
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.207 total time=   4.5s
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.406 total time=   8.7s
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.229 total time=   9.0s
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.248 total time=   9.9s
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.234 total time=   8.9s
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=nan total time=   9.2s
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.397 total time=   0.5s
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.229 total time=   0.5s
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.246 total time=   0.5s
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.239 total time=   0.5s
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.212 total time=   0.6s
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.408 total time=   0.9s
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.232 total time=   1.0s
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.246 total time=   1.0s
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.237 total time=   1.0s
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.206 total time=   0.9s
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.406 total time=   1.8s
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.229 total time=   1.8s
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.245 total time=   1.9s
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.235 total time=   2.0s
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.204 total time=   1.9s
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.405 total time=   4.6s
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.228 total time=   4.7s
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.247 total time=   4.5s
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.234 total time=   4.5s
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=500;, score=nan total time=   4.5s
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.408 total time=   9.0s
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.230 total time=   9.2s
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.254 total time=   8.9s
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.238 total time=   8.9s
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=nan total time=   9.2s
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.408 total time=   0.5s
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.232 total time=   0.5s
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.247 total time=   0.5s
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.237 total time=   0.5s
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.208 total time=   0.5s
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.408 total time=   1.0s
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.231 total time=   0.9s
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.246 total time=   0.9s
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.236 total time=   1.0s
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.205 total time=   0.9s
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.406 total time=   1.9s
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.228 total time=   1.9s
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.246 total time=   1.9s
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.233 total time=   1.8s
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.203 total time=   1.9s
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.409 total time=   4.6s
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.227 total time=   5.0s
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.252 total time=   4.7s
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.236 total time=   4.7s
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.206 total time=   4.6s
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.412 total time=   8.9s
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=nan total time=   9.3s
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.264 total time=   9.1s
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.243 total time=   8.8s
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [-0.28402852 -0.26215396 -0.26592347 -0.26353752 -0.26345615 -0.2607456
#  -0.2665837  -0.26523684 -0.26378492         nan -0.26438461 -0.26585643
#  -0.26376751         nan         nan -0.26648874 -0.26500612 -0.263137
#  -0.26603316         nan]
#   warnings.warn(
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=nan total time=   9.1s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          ['life_sq',
#                                                                           'children_school',
#                                                                           'young_all',
#                                                                           '0_17_all',
#                                                                           'build_count_panel',
#                                                                           'kindergarten_km',
#                                                                           'public_transport_station_min_walk',
#                                                                           'ID_bus_terminal',
#                                                                           'detention_facility_km',
#                                                                           'green_part_500',
#                                                                           'cafe_count_500_price_4000',
#                                                                           'cafe...
#                                                      n_estimators=100,
#                                                      n_jobs=None,
#                                                      num_parallel_tree=None,
#                                                      predictor=None,
#                                                      random_state=1,
#                                                      reg_alpha=None,
#                                                      reg_lambda=None,
#                                                      scale_pos_weight=None,
#                                                      subsample=None,
#                                                      tree_method=None,
#                                                      validate_parameters=None,
#                                                      verbosity=None))]),
#              param_grid={'model__learning_rate': [0.03, 0.05, 0.07, 0.1],
#                          'model__n_estimators': [50, 100, 200, 500, 1000]},
#              scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_xgboost_random.best_params_
# Out:
# {'model__learning_rate': 0.05, 'model__n_estimators': 50}

# %%
grid_search_xgboost_random.best_score_
# Out:
# -0.26074559872284053

# %%
X_input.columns
# Out:
# Index(['product_type', 'culture_objects_top_25', 'thermal_power_plant_raion',
#        'incineration_raion', 'oil_chemistry_raion', 'radiation_raion',
#        'railroad_terminal_raion', 'big_market_raion', 'nuclear_reactor_raion',
#        'detention_facility_raion',
#        ...
#        'cafe_count_5000_price_2500', 'cafe_count_5000_price_4000',
#        'cafe_count_5000_price_high', 'big_church_count_5000',
#        'church_count_5000', 'mosque_count_5000', 'leisure_count_5000',
#        'sport_count_5000', 'market_count_5000', 'sub_area'],
#       dtype='object', length=289)

# %%
random_20_features = X_input.columns[::15]

# %%
random_20_features
# Out:
# Index(['product_type', 'life_sq', 'children_school', 'young_all', '0_17_all',
#        'build_count_panel', 'kindergarten_km',
#        'public_transport_station_min_walk', 'ID_bus_terminal',
#        'detention_facility_km', 'green_part_500', 'cafe_count_500_price_4000',
#        'cafe_sum_1000_min_price_avg', 'market_count_1000',
#        'cafe_count_1500_price_2500', 'cafe_count_2000', 'sport_count_2000',
#        'cafe_count_3000_price_1500', 'trc_sqm_5000', 'leisure_count_5000'],
#       dtype='object')

# %%
len(random_20_features)
# Out:
# 20

# %%
X_random20 = X_input[random_20_features]

# %%
X_random20.dtypes
# Out:
# product_type                          object
# life_sq                              float64
# children_school                        int64
# young_all                              int64
# 0_17_all                               int64
# build_count_panel                    float64
# kindergarten_km                      float64
# public_transport_station_min_walk    float64
# ID_bus_terminal                        int64
# detention_facility_km                float64
# green_part_500                       float64
# cafe_count_500_price_4000              int64
# cafe_sum_1000_min_price_avg          float64
# market_count_1000                      int64
# cafe_count_1500_price_2500             int64
# cafe_count_2000                        int64
# sport_count_2000                       int64
# cafe_count_3000_price_1500             int64
# trc_sqm_5000                           int64
# leisure_count_5000                     int64
# dtype: object

# %%
numerical_cols_random = ['life_sq', 'children_school', 'young_all', '0_17_all',
       'build_count_panel', 'kindergarten_km',
       'public_transport_station_min_walk', 'ID_bus_terminal',
       'detention_facility_km', 'green_part_500', 'cafe_count_500_price_4000',
       'cafe_sum_1000_min_price_avg', 'market_count_1000',
       'cafe_count_1500_price_2500', 'cafe_count_2000', 'sport_count_2000',
       'cafe_count_3000_price_1500', 'trc_sqm_5000', 'leisure_count_5000']

# %%
categorical_cols_random = ['product_type']

# %%
preprocessor_random = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols_random),
        ('cat', categorical_transformer, categorical_cols_random)
    ])

# %%
my_pipeline1_random = Pipeline(steps=[
    ('preprocessor', preprocessor_random),
    ('model', model1),
])

# %%
my_pipeline2_random = Pipeline(steps=[
    ('preprocessor', preprocessor_random),
    ('model', model2),
])

# %%
my_pipeline3_random = Pipeline(steps=[
    ('preprocessor', preprocessor_random),
    ('model', model3),
])

# %%
scores1_random = -1 * cross_val_score(my_pipeline1_random, X_random20, y, cv=5, scoring='neg_mean_squared_log_error')

# %%
scores1_random
# Out:
# array([0.57375869, 0.38981891, 0.48663176, 0.46624965, 0.44081028])

# %%
scores1_random.mean()
# Out:
# 0.4714538578207462

# %%
scores2_random = -1 * cross_val_score(my_pipeline2_random, X_random20, y, cv=5, scoring='neg_mean_squared_log_error')

# %%
scores2_random
# Out:
# array([0.40296849, 0.23139571, 0.25084355, 0.24357507, 0.20904144])

# %%
scores2_random.mean()
# Out:
# 0.2675648533596991

# %%
scores3_random = -1 * cross_val_score(my_pipeline3_random, X_random20, y, cv=5, scoring='neg_mean_squared_log_error')
# Out:
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(

# %%
scores3_random
# Out:
# array([0.40614753, 0.22892315, 0.2505899 , 0.24015476,        nan])

# %%
scores3_random.mean()
# Out:
# nan

# %%
scores3_random_skewed = scores3_random[:-1]

# %%
scores3_random_skewed
# Out:
# array([0.40614753, 0.22892315, 0.2505899 , 0.24015476])

# %%
scores3_random_skewed.mean()
# Out:
# 0.28145383527338974

# %%
X_random20
# Out:
#         product_type  life_sq  children_school  young_all  0_17_all  \
# 0         Investment     27.0            10309      21154     23603
# 1         Investment     19.0             7759      15727     17700
# 2         Investment     29.0             6207      13028     14884
# 3         Investment     50.0            13670      28563     32063
# 4         Investment     77.0             6748      13368     15237
# ...              ...      ...              ...        ...       ...
# 30466     Investment     27.0            10311      21400     23849
# 30467     Investment     59.0             6398      11272     12508
# 30468  OwnerOccupier      NaN              264        574       646
# 30469     Investment     32.0             4635       9414     10896
# 30470     Investment     28.0             6533      13523     14994
#
#        build_count_panel  kindergarten_km  public_transport_station_min_walk  \
# 0                  184.0         0.145700                           3.299822
# 1                   90.0         0.147754                           0.783160
# 2                   60.0         0.049102                           3.945073
# 3                  201.0         0.179441                           1.579164
# 4                   35.0         0.247901                           0.857764
# ...                  ...              ...                                ...
# 30466              222.0         0.132645                           1.119101
# 30467               41.0         0.276256                           1.088544
# 30468                NaN         0.897889                           7.560163
# 30469              134.0         0.203020                           3.138330
# 30470               85.0         0.093619                           3.001814
#
#        ID_bus_terminal  detention_facility_km  green_part_500  \
# 0                    1               4.248036            0.00
# 1                    2              12.649879           25.14
# 2                    3               7.682303            1.67
# 3                    1               8.789894           17.36
# 4                    4               3.779781            3.56
# ...                ...                    ...             ...
# 30466                4               4.589571            3.38
# 30467                5               0.416625            5.64
# 30468                8              25.084813            3.33
# 30469                8              24.788893           14.85
# 30470                3               8.868202            0.00
#
#        cafe_count_500_price_4000  cafe_sum_1000_min_price_avg  \
# 0                              0                       527.78
# 1                              1                       615.38
# 2                              0                       642.86
# 3                              0                       658.33
# 4                              0                       763.45
# ...                          ...                          ...
# 30466                          0                       666.67
# 30467                          0                       699.35
# 30468                          0                      1000.00
# 30469                          0                       753.85
# 30470                          0                       581.82
#
#        market_count_1000  cafe_count_1500_price_2500  cafe_count_2000  \
# 0                      1                           2               36
# 1                      0                           2               21
# 2                      3                           0               24
# 3                      1                           1               25
# 4                      0                          30              483
# ...                  ...                         ...              ...
# 30466                  1                           2               43
# 30467                  0                          38              444
# 30468                  0                           1                7
# 30469                  0                           5               67
# 30470                  0                           1               26
#
#        sport_count_2000  cafe_count_3000_price_1500  trc_sqm_5000  \
# 0                    10                          16       4036616
# 1                    11                           4       2034942
# 2                     8                           9       1572990
# 3                    13                          10        942180
# 4                    21                         262       3503058
# ...                 ...                         ...           ...
# 30466                15                          15       2548292
# 30467                36                         230       4345915
# 30468                 3                           2        201300
# 30469                18                          26       1464521
# 30470                12                           6        646575
#
#        leisure_count_5000
# 0                       0
# 1                      10
# 2                       4
# 3                       0
# 4                      91
# ...                   ...
# 30466                   2
# 30467                  82
# 30468                   1
# 30469                   4
# 30470                   9
#
# [30471 rows x 20 columns]

# %%
X_random20.tail(10)
# Out:
#         product_type  life_sq  children_school  young_all  0_17_all  \
# 30461     Investment     19.0             4635       9414     10896
# 30462  OwnerOccupier     30.0             3889       8294      9249
# 30463     Investment     29.0            11319      22961     26095
# 30464  OwnerOccupier     51.0             3594       7706      8741
# 30465  OwnerOccupier      NaN             6398      11272     12508
# 30466     Investment     27.0            10311      21400     23849
# 30467     Investment     59.0             6398      11272     12508
# 30468  OwnerOccupier      NaN              264        574       646
# 30469     Investment     32.0             4635       9414     10896
# 30470     Investment     28.0             6533      13523     14994
#
#        build_count_panel  kindergarten_km  public_transport_station_min_walk  \
# 30461              134.0         0.417062                           0.949552
# 30462               61.0         0.726512                           3.178926
# 30463              235.0         0.225720                           2.274970
# 30464               60.0         0.414927                           1.037921
# 30465               41.0         1.048962                           3.912418
# 30466              222.0         0.132645                           1.119101
# 30467               41.0         0.276256                           1.088544
# 30468                NaN         0.897889                           7.560163
# 30469              134.0         0.203020                           3.138330
# 30470               85.0         0.093619                           3.001814
#
#        ID_bus_terminal  detention_facility_km  green_part_500  \
# 30461                8              14.544518            8.58
# 30462                5               4.113151            3.47
# 30463                1              11.415882            2.63
# 30464                4               5.152820           12.38
# 30465               13               3.939382           12.24
# 30466                4               4.589571            3.38
# 30467                5               0.416625            5.64
# 30468                8              25.084813            3.33
# 30469                8              24.788893           14.85
# 30470                3               8.868202            0.00
#
#        cafe_count_500_price_4000  cafe_sum_1000_min_price_avg  \
# 30461                          0                       872.22
# 30462                          0                       766.67
# 30463                          0                       400.00
# 30464                          0                       716.67
# 30465                          4                       914.53
# 30466                          0                       666.67
# 30467                          0                       699.35
# 30468                          0                      1000.00
# 30469                          0                       753.85
# 30470                          0                       581.82
#
#        market_count_1000  cafe_count_1500_price_2500  cafe_count_2000  \
# 30461                  0                           6               84
# 30462                  0                           1               45
# 30463                  1                           1               19
# 30464                  0                           3               32
# 30465                  1                          87             1058
# 30466                  1                           2               43
# 30467                  0                          38              444
# 30468                  0                           1                7
# 30469                  0                           5               67
# 30470                  0                           1               26
#
#        sport_count_2000  cafe_count_3000_price_1500  trc_sqm_5000  \
# 30461                22                          54       1145385
# 30462                16                          29       2276854
# 30463                 5                           9        867953
# 30464                16                          19       1313276
# 30465                42                         446       3346565
# 30466                15                          15       2548292
# 30467                36                         230       4345915
# 30468                 3                           2        201300
# 30469                18                          26       1464521
# 30470                12                           6        646575
#
#        leisure_count_5000
# 30461                   6
# 30462                  13
# 30463                   1
# 30464                   4
# 30465                 105
# 30466                   2
# 30467                  82
# 30468                   1
# 30469                   4
# 30470                   9

# %% [markdown]
# ## TOP20 + NEWLY CREATED

# %%
X_train_cleaned.shape
# Out:
# (30471, 289)

# %%
X_train_cleaned['young_male_ratio'] = X_train_cleaned.young_male/X_train_cleaned.young_all
X_train_cleaned['young_female_ratio'] = X_train_cleaned.young_female/X_train_cleaned.young_all
X_train_cleaned['work_male_ratio'] = X_train_cleaned.work_male/X_train_cleaned.work_all
X_train_cleaned['work_female_ratio'] = X_train_cleaned.work_female/X_train_cleaned.work_all
X_train_cleaned['ekder_male_ratio'] = X_train_cleaned.ekder_male/X_train_cleaned.ekder_all
X_train_cleaned['ekder_female_ratio'] = X_train_cleaned.ekder_female/X_train_cleaned.ekder_all

# %%
X_train_cleaned['0_6_male_ratio'] = X_train_cleaned['0_6_male']/X_train_cleaned['0_6_all']
X_train_cleaned['0_6_female_ratio'] = X_train_cleaned['0_6_female']/X_train_cleaned['0_6_all']
X_train_cleaned['7_14_male_ratio'] = X_train_cleaned['7_14_male']/X_train_cleaned['7_14_all']
X_train_cleaned['7_14_female_ratio'] = X_train_cleaned['7_14_female']/X_train_cleaned['7_14_all']
X_train_cleaned['0_17_male_ratio'] = X_train_cleaned['0_17_male']/X_train_cleaned['0_17_all']
X_train_cleaned['0_17_female_ratio'] = X_train_cleaned['0_17_female']/X_train_cleaned['0_17_all']
X_train_cleaned['16_29_male_ratio'] = X_train_cleaned['16_29_male']/X_train_cleaned['16_29_all']
X_train_cleaned['16_29_female_ratio'] = X_train_cleaned['16_29_female']/X_train_cleaned['16_29_all']
X_train_cleaned['0_13_male_ratio'] = X_train_cleaned['0_13_male']/X_train_cleaned['0_13_all']
X_train_cleaned['0_13_female_ratio'] = X_train_cleaned['0_13_female']/X_train_cleaned['0_13_all']

# %%
#X_train_cleaned['rel_floor'] = (X_train_cleaned.floor/X_train_cleaned.max_floor).astype(float)
#X_train_cleaned['rel_kitchen_sq'] = (X_train_cleaned.kitch_sq/X_train_cleaned.full_sq).astype(float)

# %%
numerical_cols_top = ['full_sq', '0_13_female', '7_14_female', 'work_female',
       '0_13_all', '0_17_male', 'young_female', '0_17_female', 'raion_popul',
       '7_14_male', '0_13_male', 'work_male', 'work_all', 'young_all',
       '0_17_all', 'children_school', '0_6_female', 'ekder_female',
       '0_6_male']

# %%
handcrafted_cols = ['young_male_ratio','young_female_ratio','work_male_ratio','work_female_ratio','ekder_male_ratio','ekder_female_ratio'
                   , '0_6_male_ratio','0_6_female_ratio','7_14_male_ratio','7_14_female_ratio','0_17_male_ratio','0_17_female_ratio',
                   '16_29_male_ratio','16_29_female_ratio','0_13_male_ratio','0_13_female_ratio']

# %%
numerical_cols_new = numerical_cols_top + handcrafted_cols

# %%
numerical_cols_new
# Out:
# ['full_sq',
#  '0_13_female',
#  '7_14_female',
#  'work_female',
#  '0_13_all',
#  '0_17_male',
#  'young_female',
#  '0_17_female',
#  'raion_popul',
#  '7_14_male',
#  '0_13_male',
#  'work_male',
#  'work_all',
#  'young_all',
#  '0_17_all',
#  'children_school',
#  '0_6_female',
#  'ekder_female',
#  '0_6_male',
#  'young_male_ratio',
#  'young_female_ratio',
#  'work_male_ratio',
#  'work_female_ratio',
#  'ekder_male_ratio',
#  'ekder_female_ratio',
#  '0_6_male_ratio',
#  '0_6_female_ratio',
#  '7_14_male_ratio',
#  '7_14_female_ratio',
#  '0_17_male_ratio',
#  '0_17_female_ratio',
#  '16_29_male_ratio',
#  '16_29_female_ratio',
#  '0_13_male_ratio',
#  '0_13_female_ratio']

# %%
categorical_cols_new = ['sub_area']

# %%
preprocessor_new = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols_new),
        ('sub_area', sub_area_transformer, categorical_cols_new)
    ])

# %%
my_pipeline1_new = Pipeline(steps=[
    ('preprocessor', preprocessor_new),
    ('model', model1),
])

# %%
my_pipeline2_new = Pipeline(steps=[
    ('preprocessor', preprocessor_new),
    ('model', model2),
])

# %%
my_pipeline3_new = Pipeline(steps=[
    ('preprocessor', preprocessor_new),
    ('model', model3),
])

# %% [markdown]
# ## Single Tree GRIDSEARCH

# %%
new_total_cols = numerical_cols_new + categorical_cols_new

# %%
X_new = X_train_cleaned[new_total_cols]

# %%
X_new.describe()
# Out:
#             full_sq   0_13_female   7_14_female   work_female      0_13_all  \
# count  30471.000000  30471.000000  30471.000000  30471.000000  30471.000000
# mean      54.214269   4803.833153   2610.946507  26414.414821   9841.097535
# std       38.031487   3536.907486   1941.380464  18643.132758   7290.007118
# min        0.000000    156.000000     82.000000    771.000000    322.000000
# 25%       38.000000   1512.000000    743.000000   6661.000000   3112.000000
# 50%       49.000000   4667.000000   2535.000000  26092.000000   9633.000000
# 75%       63.000000   6699.000000   3534.000000  37942.000000  13121.000000
# max     5326.000000  17461.000000   9322.000000  81668.000000  36035.000000
#
#           0_17_male  young_female   0_17_female    raion_popul     7_14_male  \
# count  30471.000000  30471.000000  30471.000000   30471.000000  30471.000000
# mean    6423.198517   5455.013948   6117.569525   84056.425552   2743.470349
# std     4769.593328   4020.546283   4491.734947   57871.285899   2054.521520
# min      214.000000    177.000000    198.000000    2546.000000     87.000000
# 25%     1973.000000   1677.000000   1858.000000   21819.000000    821.000000
# 50%     6085.000000   5333.000000   6185.000000   83502.000000   2693.000000
# 75%     8599.000000   7617.000000   8549.000000  122862.000000   3585.000000
# max    23233.000000  19715.000000  21937.000000  247469.000000   9761.000000
#
#        ...  0_6_male_ratio  0_6_female_ratio  7_14_male_ratio  \
# count  ...    30471.000000      30471.000000     30471.000000
# mean   ...        0.512006          0.488335         0.513246
# std    ...        0.012428          0.012258         0.016302
# min    ...        0.459178          0.459625         0.420637
# 25%    ...        0.505275          0.481637         0.508735
# 50%    ...        0.514590          0.485714         0.515847
# 75%    ...        0.519534          0.494725         0.522550
# max    ...        0.540375          0.540822         0.557401
#
#        7_14_female_ratio  0_17_male_ratio  0_17_female_ratio  \
# count       30471.000000     30471.000000       30471.000000
# mean            0.487045         0.513054           0.487108
# std             0.016262         0.013144           0.013068
# min             0.442599         0.452859           0.455447
# 25%             0.477450         0.510767           0.480840
# 50%             0.484897         0.515534           0.484466
# 75%             0.491265         0.520124           0.489233
# max             0.579363         0.544553           0.547141
#
#        16_29_male_ratio  16_29_female_ratio  0_13_male_ratio  \
# count      30471.000000        30471.000000     30471.000000
# mean           0.502394            0.497677         0.512083
# std            0.034702            0.034618         0.013473
# min            0.412014            0.387667         0.444224
# 25%            0.481400            0.476543         0.510106
# 50%            0.494143            0.505857         0.515487
# 75%            0.523457            0.518600         0.516850
# max            0.612430            0.587986         0.541368
#
#        0_13_female_ratio
# count       30471.000000
# mean            0.487928
# std             0.013470
# min             0.458632
# 25%             0.483150
# 50%             0.484513
# 75%             0.489894
# max             0.555776
#
# [8 rows x 35 columns]

# %%
grid_search_singletree_new = GridSearchCV(my_pipeline1_new, param_grid_singletree1, cv=5, scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_singletree_new.fit(X_new,y)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END .........model__max_leaf_nodes=50;, score=-0.403 total time=   0.1s
# [CV 2/5] END .........model__max_leaf_nodes=50;, score=-0.216 total time=   0.1s
# [CV 3/5] END .........model__max_leaf_nodes=50;, score=-0.254 total time=   0.1s
# [CV 4/5] END .........model__max_leaf_nodes=50;, score=-0.236 total time=   0.1s
# [CV 5/5] END .........model__max_leaf_nodes=50;, score=-0.216 total time=   0.1s
# [CV 1/5] END ........model__max_leaf_nodes=100;, score=-0.402 total time=   0.1s
# [CV 2/5] END ........model__max_leaf_nodes=100;, score=-0.210 total time=   0.1s
# [CV 3/5] END ........model__max_leaf_nodes=100;, score=-0.247 total time=   0.1s
# [CV 4/5] END ........model__max_leaf_nodes=100;, score=-0.234 total time=   0.1s
# [CV 5/5] END ........model__max_leaf_nodes=100;, score=-0.206 total time=   0.1s
# [CV 1/5] END ........model__max_leaf_nodes=200;, score=-0.397 total time=   0.1s
# [CV 2/5] END ........model__max_leaf_nodes=200;, score=-0.210 total time=   0.1s
# [CV 3/5] END ........model__max_leaf_nodes=200;, score=-0.247 total time=   0.1s
# [CV 4/5] END ........model__max_leaf_nodes=200;, score=-0.233 total time=   0.1s
# [CV 5/5] END ........model__max_leaf_nodes=200;, score=-0.205 total time=   0.1s
# [CV 1/5] END ........model__max_leaf_nodes=500;, score=-0.403 total time=   0.1s
# [CV 2/5] END ........model__max_leaf_nodes=500;, score=-0.218 total time=   0.1s
# [CV 3/5] END ........model__max_leaf_nodes=500;, score=-0.252 total time=   0.1s
# [CV 4/5] END ........model__max_leaf_nodes=500;, score=-0.248 total time=   0.1s
# [CV 5/5] END ........model__max_leaf_nodes=500;, score=-0.218 total time=   0.2s
# [CV 1/5] END .......model__max_leaf_nodes=1000;, score=-0.420 total time=   0.1s
# [CV 2/5] END .......model__max_leaf_nodes=1000;, score=-0.223 total time=   0.1s
# [CV 3/5] END .......model__max_leaf_nodes=1000;, score=-0.278 total time=   0.1s
# [CV 4/5] END .......model__max_leaf_nodes=1000;, score=-0.258 total time=   0.1s
# [CV 5/5] END .......model__max_leaf_nodes=1000;, score=-0.237 total time=   0.1s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          ['full_sq',
#                                                                           '0_13_female',
#                                                                           '7_14_female',
#                                                                           'work_female',
#                                                                           '0_13_all',
#                                                                           '0_17_male',
#                                                                           'young_female',
#                                                                           '0_17_female',
#                                                                           'raion_popul',
#                                                                           '7_14_male',
#                                                                           '0_13_male',
#                                                                           'work_male',
#                                                                           'work_all',
#                                                                           'young_all',
#                                                                           '0_17_all',
#                                                                           'children_school',
#                                                                           '0_6_female...
#                                                                           '0_17_male_ratio', ...]),
#                                                                         ('sub_area',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('label',
#                                                                                           OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                                          unknown_value=-1))]),
#                                                                          ['sub_area'])])),
#                                        ('model',
#                                         DecisionTreeRegressor(random_state=1))]),
#              param_grid={'model__max_leaf_nodes': [50, 100, 200, 500, 1000]},
#              scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_singletree_new.best_params_
# Out:
# {'model__max_leaf_nodes': 200}

# %%
grid_search_singletree_new.best_score_
# Out:
# -0.25846761542309815

# %% [markdown]
# ## FOREST

# %%
grid_search_forest_new = GridSearchCV(my_pipeline2_new, param_grid_forest, cv=5, scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_forest_new.fit(X_new,y)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END ...........model__n_estimators=50;, score=-0.408 total time=   6.6s
# [CV 2/5] END ...........model__n_estimators=50;, score=-0.215 total time=   6.3s
# [CV 3/5] END ...........model__n_estimators=50;, score=-0.257 total time=   6.5s
# [CV 4/5] END ...........model__n_estimators=50;, score=-0.237 total time=   6.5s
# [CV 5/5] END ...........model__n_estimators=50;, score=-0.210 total time=   6.5s
# [CV 1/5] END ..........model__n_estimators=100;, score=-0.408 total time=  12.6s
# [CV 2/5] END ..........model__n_estimators=100;, score=-0.214 total time=  12.7s
# [CV 3/5] END ..........model__n_estimators=100;, score=-0.255 total time=  12.8s
# [CV 4/5] END ..........model__n_estimators=100;, score=-0.237 total time=  13.3s
# [CV 5/5] END ..........model__n_estimators=100;, score=-0.208 total time=  13.1s
# [CV 1/5] END ..........model__n_estimators=200;, score=-0.407 total time=  25.8s
# [CV 2/5] END ..........model__n_estimators=200;, score=-0.214 total time=  26.9s
# [CV 3/5] END ..........model__n_estimators=200;, score=-0.255 total time=  24.5s
# [CV 4/5] END ..........model__n_estimators=200;, score=-0.236 total time=  26.8s
# [CV 5/5] END ..........model__n_estimators=200;, score=-0.208 total time=  27.5s
# [CV 1/5] END ..........model__n_estimators=500;, score=-0.407 total time= 1.1min
# [CV 2/5] END ..........model__n_estimators=500;, score=-0.214 total time= 1.1min
# [CV 3/5] END ..........model__n_estimators=500;, score=-0.255 total time= 1.1min
# [CV 4/5] END ..........model__n_estimators=500;, score=-0.236 total time= 1.1min
# [CV 5/5] END ..........model__n_estimators=500;, score=-0.208 total time= 1.0min
# [CV 1/5] END .........model__n_estimators=1000;, score=-0.407 total time= 2.0min
# [CV 2/5] END .........model__n_estimators=1000;, score=-0.214 total time= 2.0min
# [CV 3/5] END .........model__n_estimators=1000;, score=-0.255 total time= 2.2min
# [CV 4/5] END .........model__n_estimators=1000;, score=-0.236 total time= 2.2min
# [CV 5/5] END .........model__n_estimators=1000;, score=-0.208 total time= 2.2min
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          ['full_sq',
#                                                                           '0_13_female',
#                                                                           '7_14_female',
#                                                                           'work_female',
#                                                                           '0_13_all',
#                                                                           '0_17_male',
#                                                                           'young_female',
#                                                                           '0_17_female',
#                                                                           'raion_popul',
#                                                                           '7_14_male',
#                                                                           '0_13_male',
#                                                                           'work_male',
#                                                                           'work_all',
#                                                                           'young_all',
#                                                                           '0_17_all',
#                                                                           'children_school',
#                                                                           '0_6_female...
#                                                                           '0_17_male_ratio', ...]),
#                                                                         ('sub_area',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('label',
#                                                                                           OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                                          unknown_value=-1))]),
#                                                                          ['sub_area'])])),
#                                        ('model',
#                                         RandomForestRegressor(random_state=1))]),
#              param_grid={'model__n_estimators': [50, 100, 200, 500, 1000]},
#              scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_forest_new.best_params_
# Out:
# {'model__n_estimators': 500}

# %%
grid_search_forest_new.best_score_
# Out:
# -0.26399157234763904

# %% [markdown]
# ## XGBOOST

# %%
grid_search_xgboost_new = GridSearchCV(my_pipeline3_new, param_grid_xgboost, cv=5, scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_xgboost_new.fit(X_new,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [07:38:28] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.327 total time=   0.4s
# [07:38:28] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.206 total time=   0.5s
# [07:38:29] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.263 total time=   0.5s
# [07:38:30] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.264 total time=   0.4s
# [07:38:30] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=50;, score=-0.273 total time=   0.4s
# [07:38:31] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.365 total time=   1.0s
# [07:38:32] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.192 total time=   0.9s
# [07:38:33] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.230 total time=   1.1s
# [07:38:34] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.215 total time=   1.0s
# [07:38:35] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=100;, score=-0.196 total time=   1.0s
# [07:38:36] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.385 total time=   1.8s
# [07:38:38] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.198 total time=   1.6s
# [07:38:40] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.233 total time=   1.8s
# [07:38:42] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.213 total time=   1.9s
# [07:38:43] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=200;, score=-0.188 total time=   1.6s
# [07:38:45] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.386 total time=   3.7s
# [07:38:49] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.198 total time=   3.5s
# [07:38:53] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.233 total time=   3.7s
# [07:38:56] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.213 total time=   3.5s
# [07:39:00] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=500;, score=-0.188 total time=   3.9s
# [07:39:04] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.389 total time=   7.8s
# [07:39:12] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.200 total time=   8.0s
# [07:39:20] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.234 total time=   7.6s
# [07:39:28] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.215 total time=   8.4s
# [07:39:36] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.03, model__n_estimators=1000;, score=-0.189 total time=   8.1s
# [07:39:44] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.354 total time=   0.5s
# [07:39:45] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.189 total time=   0.5s
# [07:39:46] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.231 total time=   0.5s
# [07:39:46] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.218 total time=   0.5s
# [07:39:47] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=50;, score=-0.203 total time=   0.6s
# [07:39:47] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.383 total time=   1.1s
# [07:39:49] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.198 total time=   1.0s
# [07:39:50] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.233 total time=   0.9s
# [07:39:51] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.213 total time=   1.1s
# [07:39:52] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=100;, score=-0.188 total time=   1.0s
# [07:39:53] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.385 total time=   1.7s
# [07:39:55] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.199 total time=   1.7s
# [07:39:57] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.233 total time=   1.7s
# [07:39:58] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.213 total time=   1.6s
# [07:40:00] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=200;, score=-0.187 total time=   1.9s
# [07:40:02] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.387 total time=   4.1s
# [07:40:06] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.200 total time=   4.1s
# [07:40:11] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.235 total time=   4.3s
# [07:40:15] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.215 total time=   4.5s
# [07:40:20] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=500;, score=-0.189 total time=   3.7s
# [07:40:23] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.394 total time=   7.4s
# [07:40:31] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.203 total time=   8.1s
# [07:40:39] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [CV 3/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.237 total time=   8.3s
# [07:40:48] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.219 total time=   8.4s
# [07:40:56] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.05, model__n_estimators=1000;, score=-0.193 total time=   7.5s
# [07:41:04] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.374 total time=   0.4s
# [07:41:04] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.195 total time=   0.5s
# [07:41:05] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.232 total time=   0.5s
# [07:41:05] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.214 total time=   0.5s
# [07:41:06] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=50;, score=-0.191 total time=   0.5s
# [07:41:07] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.385 total time=   0.9s
# [07:41:08] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.198 total time=   0.8s
# [07:41:08] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.233 total time=   0.9s
# [07:41:09] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.213 total time=   0.9s
# [07:41:10] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=100;, score=-0.187 total time=   0.9s
# [07:41:11] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.388 total time=   1.5s
# [07:41:13] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.198 total time=   1.6s
# [07:41:15] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.233 total time=   1.5s
# [07:41:16] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.213 total time=   1.6s
# [07:41:18] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=200;, score=-0.187 total time=   1.6s
# [07:41:20] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.394 total time=   3.8s
# [07:41:24] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.201 total time=   3.8s
# [07:41:28] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.235 total time=   3.7s
# [07:41:31] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.216 total time=   3.7s
# [07:41:35] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=500;, score=-0.190 total time=   3.9s
# [07:41:39] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.402 total time=   9.2s
# [07:41:48] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.206 total time=   8.4s
# [07:41:57] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.242 total time=   9.6s
# [07:42:07] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.224 total time=   8.7s
# [07:42:16] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.07, model__n_estimators=1000;, score=-0.195 total time=   8.0s
# [07:42:24] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.383 total time=   0.5s
# [07:42:24] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.198 total time=   0.5s
# [07:42:25] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.233 total time=   0.5s
# [07:42:25] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.214 total time=   0.5s
# [07:42:26] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=50;, score=-0.189 total time=   0.5s
# [07:42:27] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.386 total time=   0.9s
# [07:42:28] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.198 total time=   0.8s
# [07:42:29] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.233 total time=   0.9s
# [07:42:30] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.213 total time=   0.8s
# [07:42:31] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=100;, score=-0.187 total time=   0.9s
# [07:42:32] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.388 total time=   1.6s
# [07:42:33] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.199 total time=   1.6s
# [07:42:35] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.233 total time=   1.6s
# [07:42:37] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.214 total time=   1.6s
# [07:42:38] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=200;, score=-0.189 total time=   1.6s
# [07:42:40] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.392 total time=   4.0s
# [07:42:44] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.203 total time=   4.0s
# [07:42:48] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.238 total time=   3.8s
# [07:42:52] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.220 total time=   4.0s
# [07:42:56] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=500;, score=-0.193 total time=   3.8s
# [07:43:00] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [CV 1/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.400 total time=   8.5s
# [07:43:09] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.210 total time=   8.9s
# [07:43:18] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.249 total time=   8.6s
# [07:43:27] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=-0.232 total time=   8.2s
# [07:43:35] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 199, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\zhang\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\Users\zhang\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [-0.2665385  -0.23960441 -0.24329933 -0.2434965  -0.24546403 -0.23892618
#  -0.24306812 -0.24334969 -0.24501076 -0.24919648 -0.24117304 -0.24338031
#  -0.24380985 -0.24714825 -0.25394642 -0.24340067 -0.24362291 -0.24456353
#  -0.24923567         nan]
#   warnings.warn(
# [CV 5/5] END model__learning_rate=0.1, model__n_estimators=1000;, score=nan total time=   7.9s
# [07:43:43] WARNING: C:\Windows\Temp\abs_557yfx631l\croots\recipe\xgboost-split_1659548953302\work\src\learner.cc:576:
# Parameters: { "early_stopping_rounds" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          ['full_sq',
#                                                                           '0_13_female',
#                                                                           '7_14_female',
#                                                                           'work_female',
#                                                                           '0_13_all',
#                                                                           '0_17_male',
#                                                                           'young_female',
#                                                                           '0_17_female',
#                                                                           'raion_popul',
#                                                                           '7_14_male',
#                                                                           '0_13_male',
#                                                                           'work_male',
#                                                                           'work_all',
#                                                                           'young_all',
#                                                                           '0_17_all',
#                                                                           'children_school',
#                                                                           '0_6_female...
#                                                      n_estimators=100,
#                                                      n_jobs=None,
#                                                      num_parallel_tree=None,
#                                                      predictor=None,
#                                                      random_state=1,
#                                                      reg_alpha=None,
#                                                      reg_lambda=None,
#                                                      scale_pos_weight=None,
#                                                      subsample=None,
#                                                      tree_method=None,
#                                                      validate_parameters=None,
#                                                      verbosity=None))]),
#              param_grid={'model__learning_rate': [0.03, 0.05, 0.07, 0.1],
#                          'model__n_estimators': [50, 100, 200, 500, 1000]},
#              scoring='neg_mean_squared_log_error', verbose=3)

# %%
grid_search_xgboost_new.best_params_
# Out:
# {'model__learning_rate': 0.05, 'model__n_estimators': 50}

# %%
grid_search_xgboost_new.best_score_
# Out:
# -0.23892618283781347
